# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# # verify tables in catalog

# %%
# %sql
SHOW TABLES IN learning_pradeep.pipeline

# %% [markdown]
# # verifying count to not in 0's

# %%
tables = [
 "bronze_dim_customers",
 "bronze_dim_products",
 "bronze_dim_stores",
 "bronze_dim_dates",
 "bronze_dim_campaigns",
 "bronze_dim_salespersons",
 "bronze_fact_sales_normalized"
]

for t in tables:
    df = spark.table(f"learning_pradeep.pipeline.{t}")
    print(t, df.count())

# %% [markdown]
# # schema description

# %%
spark.table("learning_pradeep.pipeline.bronze_fact_sales_normalized").printSchema()

# %% [markdown]
# # sample data

# %%
df = spark.table("learning_pradeep.pipeline.bronze_fact_sales_normalized").limit(5)
display(df)
