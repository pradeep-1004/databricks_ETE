# %%
spark.table("learning_pradeep.pipeline.bronze_fact_sales_normalized").printSchema()

# %%
spark.table("learning_pradeep.pipeline.bronze_dim_campaigns").printSchema()

# %%
spark.table("learning_pradeep.pipeline.bronze_dim_customers").printSchema()

# %%
spark.table("learning_pradeep.pipeline.bronze_dim_dates").printSchema()

# %%
spark.table("learning_pradeep.pipeline.bronze_dim_products").printSchema()

# %%
spark.table("learning_pradeep.pipeline.bronze_dim_salespersons").printSchema()

# %%
spark.table("learning_pradeep.pipeline.bronze_dim_stores").printSchema()
